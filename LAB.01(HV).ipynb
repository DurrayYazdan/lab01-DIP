# %%
DIGITAL IMAGE PROCESSING LAB-01(HV)
DURRAY YAZDAN ZAIDI (H18154022)
AREA: NOSHAHRO FEROZ, KARACHI,SINDH, PAKISTAN.
SUBMITED TO: SIR ATHESHAM

# %%
# import rasterio
from rasterio.plot import show
# import rasterio
import geotiff
import tifffile
from PIL import Image
img = Image.open("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HV-ALPSRP247640520-H2.2_UA.tif")
show(img)
pixels = img.load()

# %%
META DATA INFORMATION:

# %%
import rasterio

# Open the GeoTIFF image
with rasterio.open("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HV-ALPSRP247640520-H2.2_UA.tif") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 5700 x 4700
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 4700

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
import numpy as np
from PIL import Image

# Open the image
img = Image.open("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")

# Convert the image to a NumPy array
img_array = np.array(img)

# Calculate image statistics
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)

# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 2891.422327323628
# Standard Deviation: 1925.4344667595635
# Min: 0
# Max: 65535

# %%
width, height = img.size

# Print the results
print("Width:", width)
print("Height:", height)
# Out:
# Width: 5700
# Height: 4700

# %%
REDUCING SIZE OF THE IMAGE

# %%
from rasterio.plot import show
# import rasterio
import geotiff
import tifffile
# from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

 
try:
    # Read image from disk.
    img = cv2.imread("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")
 
    # Get number of pixel horizontally and vertically. 
    (height, width) = img.shape[:2]    
 
    # Specify the size of image along with interpolation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation=cv2.INTER_CUBIC)
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res)
 
except IOError:
    print('Error while reading files !!!')

# %%
plt.imshow(res)

# %%
ROTATING TIFF IMAGE

# %%
try:
    # Read image from disk.
    img = cv2.imread("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")
 
     # Shape of image in terms of pixels.
    (rows, cols) = img.shape[:2]
 
    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)
    res = cv2.warpAffine(img, M, (cols, rows))
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res)
 
except IOError:
    print('Error while reading files !!!')

# %%
plt.imshow(res)

# %%
TRANSLATING MATRIX

# %%
# Let's shift by (100, 50).
M = np.float32([[1, 0, 100], [0, 1, 50]])
try:
    # Read image from disk.
    img = cv2.imread("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")
 
     # warpAffine does appropriate shifting given the
    # translation matrix.
    res2 = cv2.warpAffine(img, M, (cols, rows))
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res2)
 
except IOError:
    print('Error while reading files !!!')

# %%
plt.imshow(res)

# %%
CANNY EDGE DETECTION

# %%
try:
    # Read image from disk.
    img = cv2.imread("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")
 
     
     # Canny edge detection.
    edges = cv2.Canny(img, 15, 10)
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', edges)
 
except IOError:
    print('Error while reading files !!!')

# %%
plt.imshow(edges)

# %%
RGB
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 RGB
#
# NameError: name 'RGB' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img2 = cv2.imread("C:\\Users\\kayna\\ALPSRP247640520-H2.2_UA\\HH-ALPSRP247640520-H2.2_UA.tif")

# Convert BGR to RGB color space (matplotlib expects RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img2_rgb)
plt.axis('off')  # Remove axis ticks and labels
plt.show()
